# %%
#from datetime import date , datetime , timedelta
#import locale
#import glob
#import pyperclip
#from openpyxl import load_workbook
#import shutil
#import schedule
import time
import pyautogui
import openpyxl
from pathlib import Path
import pandas as pd
import sys
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from dotenv import load_dotenv #type:igore
load_dotenv()
# Out:
# True

# %% [markdown]
# # Login

# %%
# Fazer o Login
print('Fazendo o Login na página DocuSign')
# Selecionando o caminho do Anexo
pyautogui.PAUSE = 0.5
FROM_EMAIL= os.getenv('FROM_EMAIL')
E_MAIL_PASSWORD = str(os.getenv('E_MAIL_PASSWORD'))
#Passo 1: Entrar no Chrome
navegador = webdriver.Chrome()
print('Abrindo a página')
navegador.get("https://account.docusign.com/oauth/auth?ui_locales=pt-BR&_gl=1*4u93yb*_gcl_aw*R0NMLjE3NTQzMDgwNzEuQ2owS0NRand0TUhFQmhDLUFSSXNBQnVhNWlURC1OeHU0cHRMWV83cTBtVDJqTm1hcEFaWmF5d3VaN2s1Mmp3LWhKSHdQbUp3R053YmwyZ2FBa25WRUFMd193Y0I.*_gcl_au*MTkzNzQ2Nzg2Ni4xNzU5NzUyMjE5")

# Passo 2: Fazer o login na Ferramenta DocuSign
print('Inserindo o e-mail')
navegador.find_element(By.XPATH, '/html/body/div/div/div[2]/div/main/div/div/div[2]/form/div[1]/div[2]/div/input').send_keys(FROM_EMAIL)
print('Clicar em seguir')
navegador.find_element(By.XPATH, '/html/body/div/div/div[2]/div/main/div/div/div[2]/form/div[2]/button').click()
time.sleep(5)

print('Clicar em Usar outras opções de login')
navegador.find_element(By.XPATH, '/html/body/div/div/div[2]/div/main/div/div/div[2]/div[3]/button').click()
time.sleep(1)

print('Inserindo a senha')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div[2]/div/main/div/div/div[2]/form[1]/div[1]/div[2]/div/input').send_keys('Fac@50')
print('Clicando em Inserindo a senha')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div[2]/div/main/div/div/div[2]/form[1]/div[2]/button').click()

time.sleep(4)

#navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/button').click()

#navegador.get("https://apps.docusign.com/send/home")
# Out:
# Fazendo o Login na página DocuSign
# Abrindo a página
# Inserindo o e-mail
# Clicar em seguir
# Clicar em Usar outras opções de login
# Inserindo a senha
# Clicando em Inserindo a senha

# %% [markdown]
# #    Clicar no Botão Iniciar (Enviar um envelope)

# %%
# Clicar em Iniciar
time.sleep(3)
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/button').click()
# Clicar em Envelopes
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/div/div/div[2]/div/div/span/div[1]/button/span[2]/span').click()
# Clicar em Enviar envelope
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/div/div/div[2]/div/div/span/div[2]/div/div[2]/div/div[1]/button/span[2]/span').click()

time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Clicar em Iniciar
#       2 time.sleep(3)
# ----> 3 navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/button').click()
#       4 # Clicar em Envelopes
#       5 navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div/div/div[3]/div/div/div[4]/div/div/div[2]/div/div/div[2]/div/div/div/div/div/div[2]/div/div/span/div[1]/button/span[2]/span').click()
#
# File c:\Fabio\Desenvolvimento\Varejo\Docusign\virtual\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# ...

# %% [markdown]
# # Fazer upload

# %%
# Clicar em Fazer Upload
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[1]/div[2]/div/div/div/div/div/div/div[2]/div/div/div/div[2]/div/button').click()
time.sleep(1)
# Clicar em Procurar
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[1]/div[2]/div/div/div/div/div/div/div[2]/div/div/div/div[2]/div/div/div/div[2]/div[1]/div[1]/label/span[2]/span').click()
print("informar o caminho na pasta")
time.sleep(3)

pyautogui.click(x=386, y=49)
time.sleep(3)
# Caminho do navegador Google Chrome no Windows
path_01 = r"C:\Fabio\CARREFOUR\PGR\PGR_TB\PGR_TB"
pyautogui.write(path_01)
time.sleep(3)

pyautogui.press("enter")
time.sleep(2)

print("Selecionar o arquivo")
pyautogui.click(x=596, y=137)
time.sleep(0.870)

print("Clicar em Abrir")
pyautogui.click(x=1015, y=684)
time.sleep(3)

# %% [markdown]
# # Inserir contatos

# %%
# Inserir os contatos
time.sleep(4)
print("Inserir Fábio")
pyautogui.press("TAB")                                     
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.write('Fabio Alves Cordeiro')  
#navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/div/div/div[1]/div[2]/ul/li[1]/div/div/div/div/div/div[2]/div/input').send_keys('Fabio Alves Cordeiro')
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.press("TAB")
pyautogui.write('Fabio_cordeiro@carrefour.com')
#navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[2]/div/div[2]/div/div/div/div/div[2]/div/input').send_keys('Fabio_cordeiro@carrefour.com')
time.sleep(2)

#Rodar a Página
pyautogui.hotkey("pagedown")
time.sleep(2)
#Incluir novo contato
navegador.find_element(By.XPATH, '//*[@id="add-recipients-content"]/div/div/div[6]/span/button[1]').click()
#navegador.find_element(By.XPATH, '<button data-qa="recipients-add" class="olv-button olv-ignore-transform css-l7j2e3" type="button"><span data-qa="recipients-add-start" class="css-1g6mk9s"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24" width="16" height="16" aria-hidden="true" fill="currentColor" focusable="false" data-qa="icon-element-recipientAdd"><path d="M12 3.9c1.71 0 3.1 1.39 3.1 3.1s-1.39 3.1-3.1 3.1S8.9 8.71 8.9 7s1.39-3.1 3.1-3.1M12 2C9.24 2 7 4.24 7 7s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5m9 16h-2v-2h-2v2h-2v2h2v2h2v-2h2zm-4.29-3.71A5.94 5.94 0 0 0 13 13h-2c-3.31 0-6 2.69-6 6v3h2v-3c0-2.21 1.79-4 4-4h2c.85 0 1.63.27 2.28.72z"></path></svg></span><span data-qa="recipients-add-text" class="css-16hz1ch">Adicionar destinatário</span></button>').Click()
time.sleep(2)

# %% [markdown]
# # Inserir usuario teste 2

# %%
# Inserir os contatos
print("Inserir Fábio")
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/div/div/div[1]/div[2]/ul/li[1]/div/div/div/div/div/div[2]/div/input').send_keys('Fabio Alves Cordeiro')
navegador.find_element(By.XPATH, '//*[@id="add-recipients-content"]/div/div/div[6]/span/button[1]').click()
pyautogui.press("enter")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")              Fabio_cordeiro@carrefour.com
pyautogui.press("tab")
pyautogui.write('Fabio_cordeiro@carrefour.com')
#navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[2]/div/div[2]/div/div/div/div/div[2]/div/input').send_keys('Fabio_cordeiro@carrefour.com')
time.sleep(2)
#Fabio_cordeiro@carrefour.com
#Rodar a Página
pyautogui.hotkey("pagedown")
time.sleep(2)
#Incluir novo contato
navegador.find_element(By.XPATH, '//*[@id="add-recipients-content"]/div/div/div[6]/span/button[1]').click()
#navegador.find_element(By.XPATH, '<button data-qa="recipients-add" class="olv-button olv-ignore-transform css-l7j2e3" type="button"><span data-qa="recipients-add-start" class="css-1g6mk9s"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24" width="16" height="16" aria-hidden="true" fill="currentColor" focusable="false" data-qa="icon-element-recipientAdd"><path d="M12 3.9c1.71 0 3.1 1.39 3.1 3.1s-1.39 3.1-3.1 3.1S8.9 8.71 8.9 7s1.39-3.1 3.1-3.1M12 2C9.24 2 7 4.24 7 7s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5m9 16h-2v-2h-2v2h-2v2h2v2h2v-2h2zm-4.29-3.71A5.94 5.94 0 0 0 13 13h-2c-3.31 0-6 2.69-6 6v3h2v-3c0-2.21 1.79-4 4-4h2c.85 0 1.63.27 2.28.72z"></path></svg></span><span data-qa="recipients-add-text" class="css-16hz1ch">Adicionar destinatário</span></button>').Click()
time.sleep(2)

# %%
print("Inserir Patricia")
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[1]/div/div/div/div/div/div[2]/div/input').send_keys('Patricia Andrade')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[2]/div/div[2]/div/div/div/div/div[2]/div/input').send_keys('Patricia_andrade@carrefour.com')
time.sleep(2)
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/span/button[1]').Click()
time.sleep(2)

print("Inserir Bidinoto")
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[1]/div/div/div/div/div/div[2]/div/input').send_keys('CRFLOG')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/div/div/div/div/div/div[1]/div[2]/ul/li[2]/div/div[2]/div/div/div/div/div[2]/div/input').send_keys('jose_claiton_guerra_bidinoto@carrefour.com')
time.sleep(2)
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[2]/div[2]/div/div/div/div[4]/span/button[1]').Click()
time.sleep(2)

# %%
#Inserindo as informações 
#Assunto
print('Assunto')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[4]/div[2]/div/div/div/div/div[1]/div[2]/div[1]/div[2]/div/input').send_keys('Plano Gerenciamento de Risco - CRFLOG - ')
#Mensagem de texto
print('Mensagem texto')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[3]/div/div/div/div[3]/div/div/div[4]/div[2]/div/div/div/div/div[1]/div[2]/div[2]/div/div[2]/textarea').send_keys('Prezados saudações, favor assinar o PGR da Transportadora CRFLOG (Bompreço), grato !!!')

#Proxima página
print('Próxima página')
navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[1]/div/div/div/div/div[4]/div/div[2]/div/span[2]/button').click()

# %%
# Fechar o navegador após o término do download
navegador.quit()
